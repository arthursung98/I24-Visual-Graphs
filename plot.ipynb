# %%
# Import plots, which contains a class Visualization with different methods
# to create different types of graphs.
import plot_functions

# %%
pole_num = 1
camera_num = 3

vis = plot_functions.Visualization(pole_num, camera_num);
# vis.time_space_graph(3, 0, 500)
vis.time_speed_graph(3, 0, 100)
